# %% [markdown]
# ST 2195 Qn 4

# %% [markdown]
# # Can you detect cascading failures as delays in one airport cause delays in others.

# %% [markdown]
# ## Import Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot

# %%
df2006 = pd.read_csv("2006.csv")

# %%
df2007 = pd.read_csv("2007.csv")

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# The columns we will be using is kept.

# %%
table2006 = df2006[['Year','Month','DayofMonth','DepTime','CRSDepTime','ArrTime','CRSArrTime','FlightNum','TailNum','ArrDelay','DepDelay','Origin','Dest']]

# %%
table2007 = df2007[['Year','Month','DayofMonth','DepTime','CRSDepTime','ArrTime','CRSArrTime','FlightNum','TailNum','ArrDelay','DepDelay','Origin','Dest']]

# %% [markdown]
# ## Delayed Flight

# %% [markdown]
# Now we will randomly choose a flight to find if there is cascading delay.

# %% [markdown]
# ### 2006

# %% [markdown]
# First we get the data of particular date with more than 30 mins delay. From the previous question we found that ATL is the busiest airport so we will use that airport.

# %%
flight2006 = table2006[(table2006['Month'] == 9) & (table2006['DayofMonth'] == 15) & (table2006['ArrDelay'] > 30) & (table2006['Origin'] == 'ATL')]

# %%
flight2006
# Out:
#          Year  Month  DayofMonth  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 4846111  2006      9          15   2154.0        2100   2258.0        2215
# 4847394  2006      9          15   1942.0        1920   2149.0        2111
# 4886640  2006      9          15   2210.0        1850   2355.0        2049
# 4900247  2006      9          15   1950.0        1820   2243.0        2035
# 4900266  2006      9          15   2020.0        1955   2255.0        2213
# ...       ...    ...         ...      ...         ...      ...         ...
# 5318392  2006      9          15   1014.0         915   1250.0        1133
# 5338622  2006      9          15   1356.0        1346   1648.0        1604
# 5338819  2006      9          15   1535.0        1425   1700.0        1543
# 5339014  2006      9          15   1615.0        1512   1722.0        1615
# 5339147  2006      9          15   2110.0        1943   2117.0        1944
#
#          FlightNum TailNum  ArrDelay  DepDelay Origin Dest
# ...

# %% [markdown]
# Now we randomly input a number in the code below to get the flight detail.

# %%
print(flight2006.iloc[168])
# Out:
# Year            2006
# Month              9
# DayofMonth        15
# DepTime       1050.0
# CRSDepTime       915
# ArrTime       1351.0
# CRSArrTime      1133
# FlightNum       5341
# TailNum       N972CA
# ArrDelay       138.0
# DepDelay        95.0
# Origin           ATL
# Dest             JFK
# Name: 5192570, dtype: object

# %% [markdown]
# We filter the table2006 to find the flight that will be leaving from Dest above. We use the filter of TailNum as the tail number is always the same.

# %%
flight2006_cascading = table2006[(table2006['Month'] == 9) & (table2006['DayofMonth'] == 15) & (table2006['Origin'] == 'JFK') & (table2006['TailNum'] == 'N972CA')]

# %%
flight2006_cascading
# Out:
#          Year  Month  DayofMonth  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 5192785  2006      9          15   1507.0        1240   1735.0        1412
#
#          FlightNum TailNum  ArrDelay  DepDelay Origin Dest
# 5192785       5295  N972CA     203.0     147.0    JFK  IAD

# %% [markdown]
# ### 2007

# %% [markdown]
# We repeat what is done in 2006 for 2007 using 2007 data.

# %%
flight2007 = table2007[(table2007['Month'] == 11) & (table2007['DayofMonth'] == 19 ) & (table2007['ArrDelay'] > 30) & (table2007['Origin'] == 'ATL')]

# %%
flight2007
# Out:
#          Year  Month  DayofMonth  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 6396881  2007     11          19   1700.0        1613   1825.0        1733
# 6396929  2007     11          19   1000.0         945   1250.0        1212
# 6396986  2007     11          19    810.0         810   1054.0        1021
# 6397025  2007     11          19   2130.0        2031     22.0        2304
# 6397139  2007     11          19   1930.0        1900   2115.0        2032
# ...       ...    ...         ...      ...         ...      ...         ...
# 6792216  2007     11          19   1559.0        1430   1838.0        1705
# 6797709  2007     11          19   1239.0        1000   1502.0        1220
# 6803744  2007     11          19   1631.0        1530   1930.0        1804
# 6807797  2007     11          19   1757.0        1720   2046.0        2000
# 6813868  2007     11          19   1358.0        1235   1639.0        1500
#
#          FlightNum TailNum  ArrDelay  DepDelay Origin Dest
# ...

# %%
print(flight2007.iloc[115])
# Out:
# Year            2007
# Month             11
# DayofMonth        19
# DepTime       1424.0
# CRSDepTime      1100
# ArrTime       1500.0
# CRSArrTime      1156
# FlightNum       4413
# TailNum       N753EV
# ArrDelay       184.0
# DepDelay       204.0
# Origin           ATL
# Dest             XNA
# Name: 6562232, dtype: object

# %%
flight2007_cascading = table2007[(table2007['Month'] == 11) & (table2007['DayofMonth'] == 19) & (table2007['Origin'] == 'XNA') & (table2007['TailNum'] == 'N753EV')]

# %%
flight2007_cascading
# Out:
#          Year  Month  DayofMonth  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 6561422  2007     11          19   1528.0        1226   1802.0        1512
#
#          FlightNum TailNum  ArrDelay  DepDelay Origin Dest
# 6561422       4386  N753EV     170.0     182.0    XNA  ATL
